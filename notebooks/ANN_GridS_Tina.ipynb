# %% [markdown]
# This version utilize grid search to get best parameter for model.fit from split dataset (numeric impute by mean)

# %% [markdown]
# By the end of this file
# 1) Target label encoder saved in "../models/" as 'ANN_GridS_label_encoder.joblib'
# 2) Hyperparameter grid search result saved in "../models/" as 'grid_result.pkl'
# 3) Hyperparameter grid search history saved in "../models/" as 'grid_result_history.pkl'
# 4) Model saved in "../models/" as 'ANN_GridS_model.joblib '
# 5) Model history saved in "../models/" as ANN_GridS_model_history.joblib
# 6) Classification report on the train_v3 prediction saved in ".../data/external/" as 'df_clr_ANN_GridS_X_train_v3.csv'
# 7) Classification report on the test_v3 prediction saved in ".../data/external/" as 'df_clr_ANN_GridS_X_test_v3.csv'
# 8) csv file with th original test_v3 df with prediction saved in ".../data/external/" as 'df_X_test_v3_output.csv'
#
# Custom functions used:
# 1) from ds.data.sets import load_sets_v2
# 2) from ds.models.performance import plot_model_learningcurve, plot_model_accuracy, plot_model_loss, df_classifcation_report

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Env set up

# %%
# for Tina machine only, to import .py from src/ds/
import os
current_workpath = os.getcwd()
print("Current workpath:", current_workpath)

parent_folder = os.path.dirname(current_workpath)
print("Parent_folder:", parent_folder)

import sys
sys.path.append(parent_folder+'/src')
print(sys.path[-1])
# Out:
# Current workpath: /home/tina4aiml/dev/notebooks
# Parent_folder: /home/tina4aiml/dev
# /home/tina4aiml/dev/src

# %%
rawfile_name = 'beer_reviews'
rawfile_format = '.csv'
rawfile_path = "../data/raw/"

interim_folder_path = "../data/interim/"
processed_folder_path  ="../data/processed/"
external_folder_path  ="../data/external/"
model_folder_path = "../models/"

# %% [markdown]
# # Import data

# %%
import pandas as pd
import numpy as np
from ds.data.sets import load_sets_v2

# %%
X_train_v3, y_train_v3, X_val_v3, y_val_v3, X_test_v3, y_test_v3 = load_sets_v2(path='../data/processed/', suffix='_v3')
# Out:
# X_train_v3 shape: (951968, 6)
# y_train_v3 shape: (951968,)
# X_val_v3 shape: (317323, 6)
# y_val_v3 shape: (317323,)
# X_test_v3 shape: (317323, 6)
# y_test_v3 shape: (317323,)

# %% [markdown]
# # Encore Target

# %%
from sklearn.preprocessing import LabelEncoder
import joblib

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the training set
label_encoder.fit(y_train_v3)

# Save the LabelEncoder
joblib.dump(label_encoder, model_folder_path+'ANN_GridS_label_encoder.joblib')

# Transform the target variables
y_train_v3_encoded = label_encoder.transform(y_train_v3).astype(int)
y_val_v3_encoded = label_encoder.transform(y_val_v3).astype(int)
y_test_v3_encoded = label_encoder.transform(y_test_v3).astype(int)

# Transform feature variables
X_train_v3 = X_train_v3.astype(float)
X_val_v3 = X_val_v3.astype(float)
X_test_v3 = X_test_v3.astype(float)

# %% [markdown]
# # Define Neural Network Architecture

# %%
features_names = np.load(processed_folder_path+'features_label.npy',allow_pickle=True)
features_names_n = len(features_names)
target_class = np.load(processed_folder_path+'beer_style.npy',allow_pickle=True)
target_class_n = len(target_class)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import tensorflow as tf
tf.keras.backend.clear_session()
# Out:
# 2023-07-09 14:28:13.513111: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-09 14:28:13.579179: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.keras.utils.set_random_seed(1)

input_shape = (features_names_n, )

# %%
# Function to create the TensorFlow model
def create_ANN_GridS_model(hidden_units=128, optimizer='adam', learning_rate=0.001):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(hidden_units, activation='relu', input_shape=input_shape),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(target_class_n, activation='softmax')
    ])
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) if optimizer == 'adam' else tf.keras.optimizers.SGD(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
wrapped_model = KerasClassifier(build_fn=create_ANN_GridS_model)
# Out:
# /tmp/ipykernel_25770/663270012.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   wrapped_model = KerasClassifier(build_fn=create_ANN_GridS_model)

# %%
param_grid = {
    'hidden_units': [128, 256],
    'optimizer': ['adam', 'sgd'],
    'learning_rate': [0.001, 0.01],
    'epochs': [20, 30],
    'batch_size': [32, 64]
}

# %%
grid_search = GridSearchCV(wrapped_model, param_grid, cv=3, scoring='accuracy')

grid_result = grid_search.fit(X_val_v3, y_val_v3_encoded)

ANN_GridS_model = grid_result.best_estimator_
best_params = grid_result.best_params_

print("Best Parameters:", best_params)
# Out:
# 2023-07-09 14:28:15.266024: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:15.278318: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:15.278688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:15.286898: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:15.287326: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:15.287762: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:16.181618: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:16.182285: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:16.182297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1722] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-07-09 14:28:16.182608: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-09 14:28:16.182662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3383 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/20
# 2023-07-09 14:28:18.201879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-07-09 14:28:18.205525: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f0cfb35fbb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-09 14:28:18.205564: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-07-09 14:28:18.211961: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-09 14:28:18.396558: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-09 14:28:18.520295: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6611/6611 [==============================] - 39s 5ms/step - loss: 3.7674 - accuracy: 0.1349
# Epoch 2/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.4348 - accuracy: 0.1711
# Epoch 3/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.3593 - accuracy: 0.1806
# Epoch 4/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3197 - accuracy: 0.1856
# Epoch 5/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2964 - accuracy: 0.1885
# Epoch 6/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.2805 - accuracy: 0.1914
# Epoch 7/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2686 - accuracy: 0.1937
# Epoch 8/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.2588 - accuracy: 0.1948
# Epoch 9/20
# 6611/6611 [==============================] - 41s 6ms/step - loss: 3.2487 - accuracy: 0.1964
# Epoch 10/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.2419 - accuracy: 0.1976
# Epoch 11/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.2347 - accuracy: 0.1993
# Epoch 12/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.2284 - accuracy: 0.2000
# Epoch 13/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2224 - accuracy: 0.2014
# Epoch 14/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.2145 - accuracy: 0.2031
# Epoch 15/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.2127 - accuracy: 0.2054
# Epoch 16/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2073 - accuracy: 0.2069
# Epoch 17/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2041 - accuracy: 0.2070
# Epoch 18/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.1995 - accuracy: 0.2079
# Epoch 19/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.1970 - accuracy: 0.2096
# Epoch 20/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.1948 - accuracy: 0.2108
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 4.2342 - accuracy: 0.0749
# Epoch 2/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 4.1353 - accuracy: 0.0768
# Epoch 3/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1303 - accuracy: 0.0775
# Epoch 4/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 4.1258 - accuracy: 0.0781
# Epoch 5/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 4.1207 - accuracy: 0.0788
# Epoch 6/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 4.1031 - accuracy: 0.0818
# Epoch 7/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.6835 - accuracy: 0.1420
# Epoch 8/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.5008 - accuracy: 0.1652
# Epoch 9/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.4304 - accuracy: 0.1733
# Epoch 10/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3890 - accuracy: 0.1774
# Epoch 11/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3650 - accuracy: 0.1803
# Epoch 12/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3477 - accuracy: 0.1828
# Epoch 13/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.3336 - accuracy: 0.1850
# Epoch 14/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3200 - accuracy: 0.1877
# Epoch 15/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3096 - accuracy: 0.1893
# Epoch 16/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3020 - accuracy: 0.1901
# Epoch 17/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2930 - accuracy: 0.1911
# Epoch 18/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2878 - accuracy: 0.1922
# Epoch 19/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.2807 - accuracy: 0.1937
# Epoch 20/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2755 - accuracy: 0.1940
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.7813 - accuracy: 0.1327
# Epoch 2/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.4388 - accuracy: 0.1707
# Epoch 3/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3734 - accuracy: 0.1787
# Epoch 4/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.3362 - accuracy: 0.1830
# Epoch 5/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.3104 - accuracy: 0.1875
# Epoch 6/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.2915 - accuracy: 0.1912
# Epoch 7/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2761 - accuracy: 0.1934
# Epoch 8/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.2624 - accuracy: 0.1952
# Epoch 9/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2483 - accuracy: 0.1977
# Epoch 10/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2382 - accuracy: 0.2005
# Epoch 11/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2276 - accuracy: 0.2038
# Epoch 12/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2199 - accuracy: 0.2053
# Epoch 13/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2141 - accuracy: 0.2069
# Epoch 14/20
# 6611/6611 [==============================] - 40s 6ms/step - loss: 3.2081 - accuracy: 0.2088
# Epoch 15/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.2027 - accuracy: 0.2095
# Epoch 16/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.1983 - accuracy: 0.2102
# Epoch 17/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.1915 - accuracy: 0.2121
# Epoch 18/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.1876 - accuracy: 0.2129
# Epoch 19/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 3.1844 - accuracy: 0.2138
# Epoch 20/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 3.1844 - accuracy: 0.2135
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.6021 - accuracy: 0.0736
# Epoch 2/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.5000 - accuracy: 0.0740
# Epoch 3/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.3954 - accuracy: 0.0740
# Epoch 4/20
# 6611/6611 [==============================] - 39s 6ms/step - loss: 4.3018 - accuracy: 0.0740
# Epoch 5/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.2433 - accuracy: 0.0741
# Epoch 6/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.2099 - accuracy: 0.0741
# Epoch 7/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1902 - accuracy: 0.0741
# Epoch 8/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1783 - accuracy: 0.0741
# Epoch 9/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1709 - accuracy: 0.0741
# Epoch 10/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1660 - accuracy: 0.0741
# Epoch 11/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1627 - accuracy: 0.0741
# Epoch 12/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1602 - accuracy: 0.0741
# Epoch 13/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1585 - accuracy: 0.0741
# Epoch 14/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1571 - accuracy: 0.0741
# Epoch 15/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1561 - accuracy: 0.0741
# Epoch 16/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1553 - accuracy: 0.0741
# Epoch 17/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1547 - accuracy: 0.0741
# Epoch 18/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1542 - accuracy: 0.0741
# Epoch 19/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1537 - accuracy: 0.0741
# Epoch 20/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1534 - accuracy: 0.0741
# 3306/3306 [==============================] - 5s 2ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.6075 - accuracy: 0.0739
# Epoch 2/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.5282 - accuracy: 0.0743
# Epoch 3/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.4652 - accuracy: 0.0743
# Epoch 4/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.4139 - accuracy: 0.0743
# Epoch 5/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.3732 - accuracy: 0.0743
# Epoch 6/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.3412 - accuracy: 0.0743
# Epoch 7/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.3161 - accuracy: 0.0743
# Epoch 8/20
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.2961 - accuracy: 0.0743
# Epoch 9/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.2799 - accuracy: 0.0743
# Epoch 10/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.2666 - accuracy: 0.0743
# Epoch 11/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.2554 - accuracy: 0.0743
# Epoch 12/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.2459 - accuracy: 0.0743
# Epoch 13/20
# 6611/6611 [==============================] - 36s 6ms/step - loss: 4.2377 - accuracy: 0.0743
# Epoch 14/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.2306 - accuracy: 0.0743
# Epoch 15/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.2244 - accuracy: 0.0743
# Epoch 16/20
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.
20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1513 - accuracy: 0.0743
# Epoch 11/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1512 - accuracy: 0.0745
# Epoch 12/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1507 - accuracy: 0.0747
# Epoch 13/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1474 - accuracy: 0.0747
# Epoch 14/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1496 - accuracy: 0.0748
# Epoch 15/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1498 - accuracy: 0.0748
# Epoch 16/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1494 - accuracy: 0.0747
# Epoch 17/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1448 - accuracy: 0.0749
# Epoch 18/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1407 - accuracy: 0.0750
# Epoch 19/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1340 - accuracy: 0.0750
# Epoch 20/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1300 - accuracy: 0.0751
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.2728 - accuracy: 0.0739
# Epoch 2/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1553 - accuracy: 0.0743
# Epoch 3/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1508 - accuracy: 0.0743
# Epoch 4/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1507 - accuracy: 0.0743
# Epoch 5/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1505 - accuracy: 0.0743
# Epoch 6/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1503 - accuracy: 0.0743
# Epoch 7/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1502 - accuracy: 0.0743
# Epoch 8/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1503 - accuracy: 0.0743
# Epoch 9/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1501 - accuracy: 0.0743
# Epoch 10/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1500 - accuracy: 0.0743
# Epoch 11/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1499 - accuracy: 0.0743
# Epoch 12/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1498 - accuracy: 0.0744
# Epoch 13/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 4.1497 - accuracy: 0.0744
# Epoch 14/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1495 - accuracy: 0.0744
# Epoch 15/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1493 - accuracy: 0.0745
# Epoch 16/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1490 - accuracy: 0.0746
# Epoch 17/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1486 - accuracy: 0.0749
# Epoch 18/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1484 - accuracy: 0.0750
# Epoch 19/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1483 - accuracy: 0.0751
# Epoch 20/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1472 - accuracy: 0.0751
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.3255 - accuracy: 0.0745
# Epoch 2/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1558 - accuracy: 0.0745
# Epoch 3/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1498 - accuracy: 0.0745
# Epoch 4/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1488 - accuracy: 0.0745
# Epoch 5/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1484 - accuracy: 0.0745
# Epoch 6/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1484 - accuracy: 0.0745
# Epoch 7/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1483 - accuracy: 0.0745
# Epoch 8/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1482 - accuracy: 0.0745
# Epoch 9/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1482 - accuracy: 0.0746
# Epoch 10/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1481 - accuracy: 0.0745
# Epoch 11/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1480 - accuracy: 0.0746
# Epoch 12/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1479 - accuracy: 0.0746
# Epoch 13/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1477 - accuracy: 0.0747
# Epoch 14/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1477 - accuracy: 0.0747
# Epoch 15/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1475 - accuracy: 0.0748
# Epoch 16/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1473 - accuracy: 0.0751
# Epoch 17/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1526 - accuracy: 0.0751
# Epoch 18/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1474 - accuracy: 0.0750
# Epoch 19/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1471 - accuracy: 0.0753
# Epoch 20/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1467 - accuracy: 0.0753
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 3.7483 - accuracy: 0.1313
# Epoch 2/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 3.4541 - accuracy: 0.1662
# Epoch 3/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 3.3874 - accuracy: 0.1773
# Epoch 4/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 3.3465 - accuracy: 0.1858
# Epoch 5/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 3.3173 - accuracy: 0.1897
# Epoch 6/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 3.2973 - accuracy: 0.1936
# Epoch 7/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 3.2808 - accuracy: 0.1961
# Epoch 8/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 3.2627 - accuracy: 0.1994
# Epoch 9/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 3.2490 - accuracy: 0.2019
# Epoch 10/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 3.2398 - accuracy: 0.2040
# Epoch 11/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 3.2291 - accuracy: 0.2056
# Epoch 12/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 3.2202 - accuracy: 0.2069
# Epoch 13/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 3.2132 - accuracy: 0.2084
# Epoch 14/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 3
20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1553 - accuracy: 0.0740
# Epoch 20/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1554 - accuracy: 0.0740
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1715 - accuracy: 0.0742
# Epoch 2/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1531 - accuracy: 0.0743
# Epoch 3/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 4/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 4.1534 - accuracy: 0.0743
# Epoch 5/20
# 6611/6611 [==============================] - 29s 4ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 6/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1531 - accuracy: 0.0743
# Epoch 7/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 8/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1531 - accuracy: 0.0743
# Epoch 9/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1533 - accuracy: 0.0743
# Epoch 10/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1531 - accuracy: 0.0743
# Epoch 11/20
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 12/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1531 - accuracy: 0.0743
# Epoch 13/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1531 - accuracy: 0.0743
# Epoch 14/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1533 - accuracy: 0.0743
# Epoch 15/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 16/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 17/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 18/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 19/20
# 6611/6611 [==============================] - 29s 4ms/step - loss: 4.1533 - accuracy: 0.0743
# Epoch 20/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1533 - accuracy: 0.0743
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/20
# 6611/6611 [==============================] - 34s 5ms/step - loss: 4.1955 - accuracy: 0.0744
# Epoch 2/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1515 - accuracy: 0.0745
# Epoch 3/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1515 - accuracy: 0.0745
# Epoch 4/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1514 - accuracy: 0.0745
# Epoch 5/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1514 - accuracy: 0.0745
# Epoch 6/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 4.1513 - accuracy: 0.0745
# Epoch 7/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 4.1516 - accuracy: 0.0745
# Epoch 8/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1516 - accuracy: 0.0745
# Epoch 9/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1517 - accuracy: 0.0745
# Epoch 10/20
# 6611/6611 [==============================] - 30s 5ms/step - loss: 4.1514 - accuracy: 0.0745
# Epoch 11/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1514 - accuracy: 0.0745
# Epoch 12/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1515 - accuracy: 0.0745
# Epoch 13/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1513 - accuracy: 0.0745
# Epoch 14/20
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1514 - accuracy: 0.0745
# Epoch 15/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1515 - accuracy: 0.0745
# Epoch 16/20
# 6611/6611 [==============================] - 31s 5ms/step - loss: 4.1515 - accuracy: 0.0745
# Epoch 17/20
# 6611/6611 [==============================] - 33s 5ms/step - loss: 4.1516 - accuracy: 0.0745
# Epoch 18/20
# ...
# Epoch 29/30
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1514 - accuracy: 0.0745
# Epoch 30/30
# 6611/6611 [==============================] - 39s 6ms/step - loss: 4.1514 - accuracy: 0.0745
# 3306/3306 [==============================] - 5s 2ms/step
# Epoch 1/30
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.4040 - accuracy: 0.0739
# Epoch 2/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.2263 - accuracy: 0.0740
# Epoch 3/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1909 - accuracy: 0.0740
# Epoch 4/30
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1764 - accuracy: 0.0740
# Epoch 5/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1689 - accuracy: 0.0740
# Epoch 6/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1644 - accuracy: 0.0740
# Epoch 7/30
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1614 - accuracy: 0.0740
# Epoch 8/30
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1594 - accuracy: 0.0740
# Epoch 9/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1579 - accuracy: 0.0740
# Epoch 10/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1568 - accuracy: 0.0740
# Epoch 11/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1559 - accuracy: 0.0740
# Epoch 12/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1553 - accuracy: 0.0740
# Epoch 13/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1547 - accuracy: 0.0740
# Epoch 14/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1543 - accuracy: 0.0740
# Epoch 15/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1540 - accuracy: 0.0740
# Epoch 16/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1537 - accuracy: 0.0740
# Epoch 17/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1534 - accuracy: 0.0740
# Epoch 18/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1532 - accuracy: 0.0740
# Epoch 19/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1530 - accuracy: 0.0740
# Epoch 20/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1528 - accuracy: 0.0740
# Epoch 21/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1527 - accuracy: 0.0740
# Epoch 22/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1526 - accuracy: 0.0740
# Epoch 23/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1525 - accuracy: 0.0740
# Epoch 24/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1524 - accuracy: 0.0740
# Epoch 25/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1523 - accuracy: 0.0740
# Epoch 26/30
# 6611/6611 [==============================] - 32s 5ms/step - loss: 4.1522 - accuracy: 0.0740
# Epoch 27/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1522 - accuracy: 0.0740
# Epoch 28/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1521 - accuracy: 0.0740
# Epoch 29/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1521 - accuracy: 0.0740
# Epoch 30/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1520 - accuracy: 0.0740
# 3306/3306 [==============================] - 5s 1ms/step
# Epoch 1/30
# 6611/6611 [==============================] - 37s 5ms/step - loss: 4.4100 - accuracy: 0.0743
# Epoch 2/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.2247 - accuracy: 0.0743
# Epoch 3/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1891 - accuracy: 0.0743
# Epoch 4/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1746 - accuracy: 0.0743
# Epoch 5/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1669 - accuracy: 0.0743
# Epoch 6/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1624 - accuracy: 0.0743
# Epoch 7/30
# 6611/6611 [==============================] - 37s 6ms/step - loss: 4.1594 - accuracy: 0.0743
# Epoch 8/30
# 6611/6611 [==============================] - 38s 6ms/step - loss: 4.1574 - accuracy: 0.0743
# Epoch 9/30
# 6611/6611 [==============================] - 36s 5ms/step - loss: 4.1559 - accuracy: 0.0743
# Epoch 10/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1547 - accuracy: 0.0743
# Epoch 11/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1539 - accuracy: 0.0743
# Epoch 12/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1532 - accuracy: 0.0743
# Epoch 13/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1526 - accuracy: 0.0743
# Epoch 14/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1522 - accuracy: 0.0743
# Epoch 15/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1518 - accuracy: 0.0743
# Epoch 16/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1515 - accuracy: 0.0743
# Epoch 17/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1513 - accuracy: 0.0743
# Epoch 18/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1510 - accuracy: 0.0743
# Epoch 19/30
# 6611/6611 [==============================] - 35s 5ms/step - loss: 4.1509 - accuracy: 0.0743
# Epoch 20/30
# 6611/6611 [==============================] - 39s 6ms/step - loss: 4.1507 - accuracy: 0.0743
# Epoch 21/30
# 3741/6611 [===============>..............] - ETA: 16s - loss: 4.1533 - accuracy: 0.0738
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 grid_search = GridSearchCV(wrapped_model, param_grid, cv=3, scoring='accuracy')
# ----> 3 grid_result = grid_search.fit(X_val_v3, y_val_v3_encoded)
#       5 ANN_GridS_model = grid_result.best_estimator_
#       6 best_params = grid_result.best_params_
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:1855, in Parallel.__call__(self, iterable)
#    1853     output = self._get_sequential_output(iterable)
#    1854     next(output)
# -> 1855     return output if self.return_generator else list(output)
#    1857 # Let's create an ID that uniquely identifies the current call. If the
#    1858 # call is interrupted early and that the same instance is immediately
#    1859 # re-used, this id will be used to prevent workers that were
#    1860 # concurrently finalizing a task from the previous call to run the
#    1861 # callback.
#    1862 with self._lock:
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:1784, in Parallel._get_sequential_output(self, iterable)
#    1782 self.n_dispatched_batches += 1
#    1783 self.n_dispatched_tasks += 1
# -> 1784 res = func(*args, **kwargs)
#    1785 self.n_completed_tasks += 1
#    1786 self.print_progress()
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:732, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     730         estimator.fit(X_train, **fit_params)
#     731     else:
# --> 732         estimator.fit(X_train, y_train, **fit_params)
#     734 except Exception:
#     735     # Note fit time as time until error
#     736     fit_time = time.time() - start_time
#
# File /usr/local/lib/python3.8/dist-packages/keras/wrappers/scikit_learn.py:248, in KerasClassifier.fit(self, x, y, **kwargs)
#     246     raise ValueError("Invalid shape for y: " + str(y.shape))
#     247 self.n_classes_ = len(self.classes_)
# --> 248 return super().fit(x, y, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/wrappers/scikit_learn.py:175, in BaseWrapper.fit(self, x, y, **kwargs)
#     172 fit_args = copy.deepcopy(self.filter_sk_params(Sequential.fit))
#     173 fit_args.update(kwargs)
# --> 175 history = self.model.fit(x, y, **fit_args)
#     177 return history
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
joblib.dump(grid_result, model_folder_path + 'grid_result.pkl')

grid_result_history = grid_result.cv_results_
joblib.dump(grid_result_history, model_folder_path + 'grid_result_history.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 joblib.dump(grid_result, model_folder_path + 'grid_result.pkl')
#       3 grid_result_history = grid_result.cv_results_
#       4 joblib.dump(grid_result_history, model_folder_path + 'grid_result_history.pkl')
#
# NameError: name 'grid_result' is not defined

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0000001)

# %%
ANN_GridS_history = ANN_GridS_model.fit(
                    X_val_v3, y_val_v3_encoded, 
                    validation_data=(X_val_v3, y_val_v3),
                    epochs=best_params['epochs'], 
                    batch_size=best_params['batch_size'],
                    callbacks=[early_stopping, reduce_lr])

# %%
from joblib import dump
dump(ANN_GridS_model, model_folder_path+'ANN_GridS_model.joblib')
dump(ANN_GridS_model.history, model_folder_path+'ANN_GridS_model_history.joblib')

# %% [markdown]
# # Model Performance on training data

# %%
ANN_GridS_model = joblib.load(model_folder_path+'ANN_GridS_model.joblib')
ANN_GridS_history = joblib.load(model_folder_path+'ANN_GridS_model_history.joblib')

# %%
# Model Summary
ANN_GridS_model._name = 'ANN_GridS_model'
ANN_GridS_model.summary()

# %%
# Model- learning curve on train set
from ds.models.performance import plot_model_learningcurve
plot_model_learningcurve(ANN_GridS_history.history,'NeuralNet on train_v3 - Learning curve')

# %%
# plot performance on train set
from ds.models.performance import plot_model_accuracy, plot_model_loss

plot_model_accuracy(ANN_GridS_history.history,'NeuralNet on train_v3 - Accuracy')

# %%
plot_model_loss(ANN_GridS_history.history,'NeuralNet on train_v3 - Loss')

# %%
# Predict on data
ANN_GridS_X_train_v3_predictions = np.argmax(ANN_GridS_model.predict(X_train_v3), axis=1)

# %%
# print overall performance metrics
from ds.models.performance import print_overall_model_metric
print_overall_model_metric(y_train_v3_encoded,ANN_GridS_X_train_v3_predictions, 'ANN_GridS_model','Trainset')

# %%
# Classififcation Report
from ds.models.performance import df_classifcation_report
df_classifcation_report(
    y_encoded = y_train_v3_encoded, 
    y_prediction = ANN_GridS_X_train_v3_predictions, 
    target_names = target_class,
    filename = 'df_clr_ANN_GridS_X_train_v3.csv', 
    dest = external_folder_path
    )

# %% [markdown]
# # Model Performance on test data

# %%
y_test_v3_pred_probs = ANN_GridS_model.predict(X_test_v3)
y_test_v3_pred = y_test_v3_pred_probs.argmax(axis=1)
y_test_v3_pred

# %%
print_overall_model_metric(y_test_v3_encoded, y_test_v3_pred, 'ANN_GridS_model','Testset')

# %%
# Classification report
df_classifcation_report(
    y_encoded = y_test_v3_encoded, 
    y_prediction = y_test_v3_pred, 
    target_names = target_class,
    filename = 'df_clr_ANN_GridS_X_test_v3.csv', 
    dest = external_folder_path
    )

# %%
# Load the saved LabelEncoder
label_encoder = joblib.load(model_folder_path+'ANN_GridS_label_encoder.joblib')

# Revert the encoded labels back to their original text form
y_test_v3_pred_decoded = label_encoder.inverse_transform(y_test_v3_pred)
y_test_v3_pred_decoded

# %% [markdown]
# # Assemble back to df

# %%
df_X_test_v3_unencoded = pd.read_pickle(interim_folder_path + 'df_X_test_v3_unencoded.pkl')
df_X_test_v3_unencoded['prediction'] = y_test_v3_pred_decoded
df_X_test_v3_unencoded.to_csv(external_folder_path+'df_X_test_v3_output.csv', index=True)
